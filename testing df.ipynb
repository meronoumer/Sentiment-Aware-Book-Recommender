# %%
import pandas as pd

# %%
df = pd.read_csv("books.csv")
df.head()
# Out:
#              id                                         title  \
# 0  0bJkAAAAMAAJ               Dystopian Fiction East and West
# 1  WMDajfrpOHoC                            Illinois Libraries
# 2  ghoTAAAAYAAJ                      The Annual Library Index
# 3  EB6kSA4Cmc0C  The Parliamentary Debates (official Report).
# 4  fbalcSRJLS8C                       Collected Short Fiction
#
#                                            author  \
# 0                                  Erika Gottlieb
# 1                                             NaN
# 2  William Isaac Fletcher, Helen Elizabeth Haines
# 3       Great Britain. Parliament. House of Lords
# 4                                Roger F. Kennedy
#
#                                          description         genres  \
# 0  "Erika Gottlieb explores a selection of about ...        History
# 1  Includes proceedings of the Illinois Library A...      Libraries
# 2  Includes periodicals, American and English; es...   Bibliography
# ...
