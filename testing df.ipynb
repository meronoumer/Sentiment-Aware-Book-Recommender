# %%
import pandas as pd

# %%
df = pd.read_csv("books.csv")
df.head()
# Out:
#              id                                         title  \
# 0  0bJkAAAAMAAJ               Dystopian Fiction East and West
# 1  WMDajfrpOHoC                            Illinois Libraries
# 2  t3vYN_ln2U4C                            Editor & Publisher
# 3  EB6kSA4Cmc0C  The Parliamentary Debates (official Report).
# 4  TuDQrUPsp7wC                          The Federal Reporter
#
#                                       author  \
# 0                             Erika Gottlieb
# 1                                        NaN
# 2                                        NaN
# 3  Great Britain. Parliament. House of Lords
# 4                                        NaN
#
#                                          description  \
# 0  "Erika Gottlieb explores a selection of about ...
# 1  Includes proceedings of the Illinois Library A...
# 2                                 The fourth estate.
# 3  Contains the 4th session of the 28th Parliamen...
# ...
